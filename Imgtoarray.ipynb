# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image #

# %%
image=Image.open(r'Pictures\image-resources2.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_arr=np.asarray(image)
image_arr
# Out:
# array([[[254, 225, 185],
#         [254, 225, 185],
#         [254, 225, 185],
#         ...,
#         [  3, 162, 204],
#         [  3, 162, 204],
#         [  3, 162, 204]],
#
#        [[254, 225, 185],
#         [254, 225, 185],
#         [254, 225, 185],
#         ...,
#         [  1, 162, 204],
#         [  1, 162, 204],
#         [  1, 162, 204]],
#
#        [[254, 225, 185],
#         [254, 225, 185],
#         [254, 225, 185],
#         ...,
#         [  3, 164, 206],
#         [  3, 164, 206],
#         [  3, 164, 206]],
#
#        ...,
#
#        [[237,   0,  94],
#         [237,   0,  94],
#         [237,   0,  95],
#         ...,
#         [ 22,   4,   0],
#         [ 21,   4,   0],
#         [ 20,   3,   0]],
#
#        [[221,   0,  86],
#         [222,   0,  87],
#         [222,   0,  87],
#         ...,
#         [ 18,   3,   0],
#         [ 19,   4,   0],
#         [ 20,   6,   0]],
#
#        [[214,   0,  86],
#         [215,   0,  87],
#         [216,   0,  87],
# ...

# %%
plt.imshow(image_arr)
plt.show()

# %%
image_arr.shape
# Out:
# (667, 1000, 3)
