# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a=np.array([[1,2,3,4],[4,5,6,7]])
a
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
np.array([11,23,24], dtype="float")
# Out:
# array([11., 23., 24.])
